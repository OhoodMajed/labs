# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification and KNN with NHL data
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# Below you will practice KNN classification on a dataset of NHL statistics.
#
# You will be predicting the `Rank` of a team from predictor variables of your choice.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# web location:
local_csv = '../data/NHL_Data_GA.csv'

# %% [markdown]
# ### 1. Load the NHL data

# %%
# A:
df=pd.read_csv('./data/NHL_Data_GA.csv')

# %% [markdown]
# ### 2. Perform any required data cleaning. Do some EDA.

# %%
# A:
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Team    90 non-null     str
#  1   PTS     90 non-null     int64
#  2   Rank    90 non-null     int64
#  3   TOI     90 non-null     str
#  4   GF      90 non-null     int64
#  5   GA      90 non-null     int64
#  6   GF60    90 non-null     float64
#  7   GA60    90 non-null     float64
#  8   GF%     90 non-null     float64
#  9   SF      90 non-null     int64
#  10  SA      90 non-null     int64
#  11  SF60    90 non-null     float64
#  12  SA60    90 non-null     float64
#  13  SF%     90 non-null     float64
#  14  FF      90 non-null     int64
#  15  FA      90 non-null     int64
#  16  FF60    90 non-null     float64
#  17  FA60    90 non-null     float64
#  18  FF%     90 non-null     float64
#  19  CF      90 non-null     int64
#  20  CA      90 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# Team    0
# PTS     0
# Rank    0
# TOI     0
# GF      0
# GA      0
# GF60    0
# GA60    0
# GF%     0
# SF      0
# SA      0
# SF60    0
# SA60    0
# SF%     0
# FF      0
# FA      0
# FF60    0
# FA60    0
# FF%     0
# CF      0
# CA      0
# CF60    0
# CA60    0
# CF%     0
# Sh%     0
# Sv%     0
# PDO     0
# PIM     0
# dtype: int64

# %%
df['Rank'].value_counts().sort_index()
# Out:
# Rank
# 1    29
# 2    30
# 3    31
# Name: count, dtype: int64

# %%
# Summary statistics for numeric features
df.describe()
# Out:
#               PTS       Rank          GF          GA       GF60       GA60  \
# count   90.000000  90.000000   90.000000   90.000000  90.000000  90.000000
# mean    91.977778   2.022222   83.288889   83.288889   2.442222   2.444000
# std     12.524114   0.820767   10.376339    9.694484   0.325331   0.313522
# min     62.000000   1.000000   57.000000   64.000000   1.700000   1.730000
# 25%     82.250000   1.000000   76.000000   75.500000   2.232500   2.202500
# 50%     92.500000   2.000000   84.000000   84.000000   2.400000   2.495000
# 75%    102.000000   3.000000   90.000000   89.000000   2.600000   2.670000
# max    121.000000   3.000000  115.000000  107.000000   3.450000   3.240000
#
#              GF%           SF           SA       SF60  ...        FF%  \
# count  90.000000    90.000000    90.000000  90.000000  ...  90.000000
# mean   49.981111  1068.333333  1068.333333  31.252222  ...  49.966667
# std     4.644554    95.929047    75.514118   2.237637  ...   2.797913
# ...

# %% [markdown]
# ### 3. Set up the `Rank` variable as your target. How many classes are there?

# %%
# A:
y = df['Rank']

num_classes = y.nunique()
num_classes
# Out:
# 3

# %% [markdown]
# ### 4. What is the baseline accuracy?

# %%
baseline = df['Rank'].value_counts().max() / len(df)
baseline
# Out:
# np.float64(0.34444444444444444)

# %% [markdown]
# ### 5. Choose 4 features to be your predictor variables and set up your design matrix.

# %%
df.columns
# Out:
# Index(['Team', 'PTS', 'Rank', 'TOI', 'GF', 'GA', 'GF60', 'GA60', 'GF%', 'SF',
#        'SA', 'SF60', 'SA60', 'SF%', 'FF', 'FA', 'FF60', 'FA60', 'FF%', 'CF',
#        'CA', 'CF60', 'CA60', 'CF%', 'Sh%', 'Sv%', 'PDO', 'PIM'],
#       dtype='str')

# %%
X = df[['PTS', 'GF', 'GA', 'PDO']]
y = df['Rank']

print(f"feature (X) shape: {X.shape}")
print(f"Target (y) shape: {y.shape}")

# Preview top rows 
X.head()
# Out:
# feature (X) shape: (90, 4)
# Target (y) shape: (90,)
#    PTS   GF  GA   PDO
# 0  121  115  73  1034
# 1  117   94  72  1014
# 2  113   90  68  1019
# 3  112  104  83   992
# 4  111   86  74  1013

# %% [markdown]
# ### 6. Fit a `KNeighborsClassifier` with 1 neighbor using the target and predictors.

# %%
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# ### 7. Evaluate the accuracy of your model.
# - Is it better than baseline?
# - Is it legitimate?

# %%
accuracy = knn.score(X, y)
accuracy
# Out:
# 1.0

# %% [markdown]
# **Is it better than baseline?**
#
# Yes. The model accuracy is 1.0 (100%), which is much higher than the baseline accuracy of 34.4%.
#
# **Is it legitimate?**
#
# No. The model was evaluated on the same data it was trained on, so the accuracy is overly optimistic. A train/test split or cross-validation is needed to evaluate its true performance.

# %% [markdown]
# ### 8. Create a 50-50 train-test-split of your target and predictors. Refit the KNN and assess the accuracy.

# %%
# A:
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50,stratify=y, random_state=42)

ss = StandardScaler()
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
accuracy = knn.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8444444444444444

# %% [markdown]
# ### 9. Evaluate the test accuracy of a KNN where K == number of rows in the training data.

# %%
# A:
k = X_train.shape[0]

knn = KNeighborsClassifier(n_neighbors=k)

knn.fit(X_train, y_train)

accuracy = knn.score(X_test, y_test)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3111111111111111

# %% [markdown]
# ### 10. Fit the KNN at values of K from 1 to the number of rows in the training data.
# - Store the test accuracy in a list.
# - Plot the test accuracy vs. the number of neighbors.

# %%
# A:
test_accuracy = []
for k in range(1, X_train.shape[0] + 1):
    
    knn = KNeighborsClassifier(n_neighbors=k)
    
    knn.fit(X_train, y_train)
    
    accuracy = knn.score(X_test, y_test)
    
    test_accuracy.append(accuracy)


plt.figure(figsize=(10, 5))

plt.plot(
    range(1, X_train.shape[0] + 1),
    test_accuracy,
    marker='o'
)

plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Test Accuracy")
plt.title("KNN Test Accuracy vs K")
plt.grid()

plt.show()

# %% [markdown]
# ### 11. Fit KNN across different values of K and plot the mean cross-validated accuracy with 5 folds.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

cv_accuracy = []

# maximum possible K for 5-fold CV
max_k = int(X_train.shape[0] * 0.8)

for k in range(1, max_k + 1):

    knn = KNeighborsClassifier(n_neighbors=k)

    scores = cross_val_score(
        knn,
        X_train,
        y_train,
        cv=5,
        scoring='accuracy'
    )

    cv_accuracy.append(scores.mean())


plt.figure(figsize=(10,5))

plt.plot(
    range(1, max_k + 1),
    cv_accuracy,
    marker='o'
)

plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Mean Cross-Validated Accuracy")
plt.title("KNN 5-Fold Cross Validation")

plt.grid()
plt.show()

# %% [markdown]
# ### 12. Standardize the predictor matrix and cross-validate across the different K.
# - Plot the standardized mean cross-validated accuracy against the unstandardized. Which is better?
# - Why?

# %%
ss = StandardScaler()

X_train_scaled = ss.fit_transform(X_train)

cv_accuracy_scaled = []

maxk = int(X_train.shape[0] * 0.8)

for k in range(1, maxk + 1):

    knn = KNeighborsClassifier(n_neighbors=k)

    scores = cross_val_score(
        knn,
        X_train_scaled,
        y_train,
        cv=5,
        scoring='accuracy'
    )

    cv_accuracy_scaled.append(scores.mean())



plt.figure(figsize=(10,5))

plt.plot(
    range(1, maxk + 1),
    cv_accuracy,
    marker='o',
    label='Unstandardized'
)

plt.plot(
    range(1, maxk + 1),
    cv_accuracy_scaled,
    marker='o',
    label='Standardized'
)


plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Mean Cross-Validated Accuracy")
plt.title("KNN: Standardized vs Unstandardized")

plt.legend()
plt.grid()
plt.show()

# %%
print("Best Unstandardized:", max(cv_accuracy))
print("Best Standardized:", max(cv_accuracy_scaled))
# Out:
# Best Unstandardized: 0.8
# Best Standardized: 0.7555555555555554

# %% [markdown]
# ## What was the best 'k'?
#
# Using `GridSearch` & `Pipeline` find the best `k` for the KNN model

# %%
pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])


param_grid = {
    'knn__n_neighbors': range(1, int(X_train.shape[0]*0.8) + 1)
}
grid = GridSearchCV(
    pipe,
    param_grid,
    cv=5,
    scoring='accuracy'
)

grid.fit(X_train, y_train)
print("Best K:", grid.best_params_['knn__n_neighbors'])
print("Best Accuracy:", grid.best_score_)
# Out:
# Best K: 19
# Best Accuracy: 0.8
