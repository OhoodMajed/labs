# %% [markdown]
# # Introduction to Python Exercises:
# ---

# %% [markdown]
# ---
# ### Part 1: Data Types
# There are two main types of data types Primitive & Non-Primitive:

# %% [markdown]
# ### 1. Primitive Data Types:
# They are basic data types and the building blocks for data manipulation and contain pure, simple values of data.
# ```python
#    #Integers: Whole numbers and referred to
#    int
#    #Float: Whole numbers and  referred to
#    float
#    #Strings: Text and referred to
#    str
#    #Boolean: True or False and referred to
#    bool
#
# ```

# %% [markdown]
# #### Identifying data type: Python has a function that helps in identifying the data type from a value or variable, called 'type'.
#
# - Instructions: type in different values inside the type() function to see what pops up

# %%
# show the type of the number 23
type(23)
# Out:
# int

# %%
# show the type of the number 23.43
type(23.43)
# Out:
# float

# %%
# show the type of the word "Hello"
type("Hello")
# Out:
# str

# %%
# show the type of the boolean True
type(True)
# Out:
# bool

# %% [markdown]
# #### __Variable:__
# A variable is a labeled container that is used to store value(s). Look at it as a box where you label it with a name and store your item(s) in it.
#
# **What is the purpose of a variable?**
#
# It is to store, reference, and manipulate information.
#
# **Naming Variables:**
# * A variable name must start with a letter or the underscore character
# * A variable name cannot start with a number
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# * Variable names are case-sensitive (number, Number, and NUMBER are three different variables)
# * A variable name cannot be any of the Python keywords.

# %%
# >> Instructions: Follow the comments step-by-step
# We will create a variable named 'score' and assign it a value of '90'. Note: to assign a value we use '='
score=90

# To display a variable we use the 'print' function. This is an example of referencing a variable
# print the score variable
print(score)

# To manipulate a variable, Add 1 to the score value and update it. 
# Score should be 91.
score=score+1
print(score)
# Out:
# 90
# 91

# %% [markdown]
# #### **Operators and Updating Variables**

# %%
# Define numeric variables for the month and day of your birthdate to be used whenever requested
month =12    # write the month of your birthdate
day =6    # write the day of your birthdate
# Write a new line of code beneath each comment, 
# always updating the birthdate variable as you do so

birthdate = 7

# %%
# Multiply birthdate variable by the month of your birthday
# save the result back into birthdate variable.
birthdate=birthdate*month
birthdate
# Out:
# 84

# %%
# Subtract 1
birthdate=birthdate-1
birthdate
# Out:
# 83

# %%
# Multiply by 13
birthdate=birthdate*13
birthdate
# Out:
# 1079

# %%
# Add the day of your birth
birthdate=birthdate+day
birthdate
# Out:
# 1085

# %%
# Add 3
birthdate=birthdate+3
birthdate
# Out:
# 1088

# %%
# Multiply by 11
birthdate=birthdate*11
birthdate
# Out:
# 11968

# %%
# Subtract the month of your birth
birthdate=birthdate-month
birthdate
# Out:
# 11956

# %%
# Subtract the day of your birth
birthdate=birthdate-day
birthdate
# Out:
# 11950

# %%
# Divide by 10
birthdate=birthdate/10
birthdate
# Out:
# 1195.0

# %%
# Add 11
birthdate=birthdate+11
birthdate
# Out:
# 1206.0

# %%
# Divide by 100
birthdate=birthdate/100
birthdate
# Out:
# 12.06

# %%
# birthdate should now be a floating point number with the day.month of your birthday
birthdate
# Out:
# 12.06

# %% [markdown]
# ### **Strings:**

# %% [markdown]
# **String concatenation**

# %%
# Introduce Yourself
greeting= 'Hello'
name= 'Ahmed'
mood= 'excited'


# print a message that is a group of strings concatinated with each other by +
# your message will be:
# Hello, my name is Ahmed and I am excited about learning python.

print(greeting+', my name is '+name+' and I am '+mood+' about learning python.')
# Out:
# Hello, my name is Ahmed and I am excited about learning python.

# %% [markdown]
# **f-strings:** is a quick way to insert and format strings.
#
# Syntax:
# ```python
# # Adding f before the string
# f"This is {variable}"
# ```

# %%
# Let's try modifying our previous message
# print the same message in previous cell using f-string
month = 12
day = 6
birthdate =7

# Print the message using an f-string
print(f"My birthdate details: Month is {month}, Day is {day}, and the calculated birthdate value is {birthdate}.")
# Out:
# My birthdate details: Month is 12, Day is 6, and the calculated birthdate value is 7.

# %% [markdown]
# #### **Code Fast and Break Things**

# %% [markdown]
# - Each of the following lines of code is mistaken in some way
# - Either they contain errors or don't do what the user would expect them to
# - Correct each example, and write a comment explaining what went wrong

# %%
# A.
my_variable ='R'
print(my_variable)
# Out:
# R

# %%
# B.
# Why didn't it print 10?
my_number = 5
my_number =my_number+ 5 
print(my_number)
# Out:
# 10

# %%
# C.
my_num = 5
my_string = "Hello"
print(str(my_num) + my_string)
# Out:
# 5Hello

# %%
# D.
# The user expected the result to be 30!
my_num1 = "10"
my_num2 = "20"
print(int(my_num1 )+ int(my_num2))
# Out:
# 30

# %%
# E.
# The user expected the message to read "I enjoy python in the morning."
language = "python"
print(f"I enjoy {language} in the morning")
# Out:
# I enjoy python in the morning

# %%
# F.
# The user expected the message to read "There are 2 plums at home for me"
# two errors are here. Try to find them one by one
number_of_plums = 2
who_plums_are_for = 'me' 
print(f"There are {number_of_plums} plums at home for {who_plums_are_for}")
# Out:
# There are 2 plums at home for me

# %% [markdown]
# ### Part 2: Collections

# %% [markdown]
# ### **Lists**

# %%
# We have a list of fruits, let's print each fruit in the list separately.
fruits = ["banana", "orange", "apple"]

# %%
# Let's change 'banana' to 'kiwi' & 'orange' to 'strawberry'
fruits[0]="kiwi"
fruits[1]="strawberry"

# The fruits list should now looks like ["kiwi", "strawberry", "apple"]
fruits
# Out:
# ['kiwi', 'strawberry', 'apple']

# %% [markdown]
# #### List methods

# %%
# We have a list of fruits to buy
fruits = ["orange"]
# We need to add 'kiwi' to our list. Using append()
fruits.append("kiwi")

# fruits is now: ["orange", "kiwi"]
print(fruits)
# Out:
# ['orange', 'kiwi']

# %%
# Maybe we should get 'lemon' before 'kiwi' . Using insert()
fruits.insert(1,"lemon")

# fruits is now: ["orange", "lemon", "kiwi"]
print(fruits)
# Out:
# ['orange', 'lemon', 'kiwi']

# %%
# Remove the 'kiwi' from our list. Using pop()
fruits.pop()

# fruits is now: ["orange", "lemon"]
print(fruits)

# Remove 'orange' too using pop() pointing to the index of it
fruits.pop(0)

# fruits is now: ["lemon"]
print(fruits)
# Out:
# ['orange', 'lemon']
# ['lemon']

# %%
# You have a List of 10 countries to Travel to
countries=['South Korea', 'Turkey', 'Oman', "Japan", 'Trinidad and Tobago', 'Germany', 'Singapore', 'Norway', 'South Africa', 'Iceland']

# Print the first country
print(countries[0])

# Print the last country

print(countries[9])
# Out:
# South Korea
# Iceland

# %%
# Find me the location of 'Germany' in the list. Using index()
print(countries.index("Germany"))

# Print the first 5 countries
print(countries[:5])

# Print the last 5 countries
print(countries[-5:])

# print 1 skip 1 from the countries starting from the first (using stepsize 2 in slicing)
print(countries[::2])
# Out:
# 5
# ['South Korea', 'Turkey', 'Oman', 'Japan', 'Trinidad and Tobago']
# ['Germany', 'Singapore', 'Norway', 'South Africa', 'Iceland']
# ['South Korea', 'Oman', 'Trinidad and Tobago', 'Singapore', 'South Africa']

# %%
# Sort the list. Using listname.sort()
countries.sort()

print("Sorted list:")
print(countries)
# Out:
# Sorted list:
# ['Germany', 'Iceland', 'Japan', 'Norway', 'Oman', 'Singapore', 'South Africa', 'South Korea', 'Trinidad and Tobago', 'Turkey']

# %%
number = [11,17,16,7,5,6,12,18,1,13,10,8,3,7,12,20,19,21,4,9,14,7,2,15]

# Get the Minimum of the list using Min(listname)
print(min(number))

# # Get the Maximum of the list using Max(listname)
print(max(number))

# Count how many 7's are in our number list using list.count()
print(number.count(7))

# how many items/count of numbers in our list. Use len(listname)
print(len(number))

# Sum all the items in the list using sum(listname)

print(sum(number))

# Cauculate the Average (Mean), the sum of all items divided by the count of them
# note: there is a direct way to get the mean, it will be covered later
Average=sum(number)/len(number)
print(Average)
# Out:
# 1
# 21
# 3
# 24
# 257
# 10.708333333333334

# %%
teamA = ['Oliver','Emma', 'Mia','Lucas']
teamB = ['John','Isabella','Stephen', 'Nadia']
# Combine teamA with teamB. Using + 
# print the result
print(teamA+teamB)

# Combine teamA with teamB. Using extend()
teamA.extend(teamB)
print(teamA)
# Out:
# ['Oliver', 'Emma', 'Mia', 'Lucas', 'John', 'Isabella', 'Stephen', 'Nadia']
# ['Oliver', 'Emma', 'Mia', 'Lucas', 'John', 'Isabella', 'Stephen', 'Nadia']

# %%
colors=['Blue','Green','Yellow']
new_colors= colors

# Let's add 'Red' to new_colors
new_colors.append('Red')
print(colors, new_colors)

# What if we remove 'Red' from colors
colors.remove('Red')
print(colors, new_colors)
# Out:
# ['Blue', 'Green', 'Yellow', 'Red'] ['Blue', 'Green', 'Yellow', 'Red']
# ['Blue', 'Green', 'Yellow'] ['Blue', 'Green', 'Yellow']

# %% [markdown]
# ##### **The Wait List**

# %%
# You will have to research some new methods to use for these challenges
# You can use print statements to investigate whether your changes have succeeded as expected
candidates = ["Alice", "Boris", "Carmen"]

# A. A promising new applicant, Diego, needs to be added to the end of the list
candidates.append("Diego")
print(candidates)

# B. Alice has informed us of a typo on their application: change their name to "Alyce"

candidates[0] = "Alyce"
print(candidates)
# Out:
# ['Alice', 'Boris', 'Carmen', 'Diego']
# ['Alyce', 'Boris', 'Carmen', 'Diego']

# %%
# C. One of our generous donors has a nephew, Aaron, who should be added to the very front of the list
candidates.insert(0,'Aaron')
candidates
# Out:
# ['Aaron', 'Alyce', 'Boris', 'Carmen', 'Diego']

# %%
# D. Boris's parents are concerned. Use the .index() method to print a message explaining Boris's place in the list
# your output should be:
# Boris is currently at location 2 in the list
boris_index=candidates.index("Boris")
print(f"Boris is currently at location {boris_index} in the list")
# Out:
# Boris is currently at location 2 in the list

# %%
# E. Carmen is upset by the priority given to relatives of donors, and has withdrawn their application.
# Use the .remove() method to remove them from the list.
candidates.remove('Carmen')
candidates
# Out:
# ['Aaron', 'Alyce', 'Boris', 'Diego']

# %%
# F. Use a method to remove the very first student in the list, as they have now been accepted!
# use pop() and specifify the index
candidates.pop(0)
candidates
# Out:
# ['Alyce', 'Boris', 'Diego']

# %%
# G. DeSean has submitted an impressive personal statement. Place them at index 1 by using .insert()
candidates.insert(1,'DeSean')
candidates
# Out:
# ['Alyce', 'DeSean', 'Boris', 'Diego']

# %%
# H. We've been audited by the Board for Educational Fairness! 
# Print the list of candidates.
# It should look like this: ["Alyce", "DeSean", Boris", "Diego"]
print(candidates)
# Out:
# ['Alyce', 'DeSean', 'Boris', 'Diego']

# %% [markdown]
# ### **Tuples:**

# %%
t1=(3,5,2,1)
t2=(3,'C',4.3,'C',5,'D')

# Print the first value of t1
print('first value in t1:',t1[0])

# Change the 2nd value in t2 to 'E', Are you able to that? Why not?
t2[1]='E' 
# No, you cannot do that because it is 'tuple' object does not support item assignment.
# Out:
# first value in t1: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       4 # Print the first value of t1
#       5 print('first value in t1:',t1[0])
#       6
#       7 # Change the 2nd value in t2 to 'E', Are you able to that? Why not?
# ----> 8 t2[2]='E'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### **Sets:**

# %%
number_set={1,40,32,56,2,32,20,1,21}

# Print number_set
print(number_set)

# Print the first value, Are you able to do it? Why is that?
#first_value=number_set[0] 
#print(first_value)
#No we cannot do it ,because sets in Python are unordered, meaning they do not support indexing.

# Sort the number_set using sorted(number_set), What is the output type? why is that?
sorted(number_set)
#Output type: list
# Why: Because a set is inherently unordered and cannot hold a specific order. 
# The sorted() function takes the elements, sorts them, and returns them in a new 'list'.
# Out:
# {32, 1, 2, 20, 21, 40, 56}
# [1, 2, 20, 21, 32, 40, 56]

# %%
popular_cars={'Ferrari','Nissan', 'Ford', 'Toyota', 'BMW', 'Audi'}
showroom_cars={'GMC','Nissan','BYC', 'Ford','Tesla', 'Jeep','Toyota', 'BMW'}

# Print the popular ones that are also in the showroom. Using  &
print(popular_cars & showroom_cars)

# Print the unpopular that are also in the showroom. Using -
print(showroom_cars - popular_cars)

# Print all car names, that is union both sets. Using |
print(popular_cars | showroom_cars)
# Out:
# {'BMW', 'Toyota', 'Ford', 'Nissan'}
# {'GMC', 'Jeep', 'Tesla', 'BYC'}
# {'GMC', 'Tesla', 'BMW', 'Jeep', 'Toyota', 'Ferrari', 'Nissan', 'BYC', 'Ford', 'Audi'}

# %% [markdown]
# ### **Dictionaries:**

# %%
talabat = { "item_name": "tomatoes", "category": "food", "price": 1.99 }

# Print the first element (item_name), can you use talabat[0]? why not?

#No, we cannot use talabat[0] Because a dictionary uses "Keys" (like strings) to access values, not numeric indexes.


# Print the category
print(talabat["category"])
# Out:
# food

# %%
# What happens if we have two price entries in the dictionary? try the code below
talabat = { "item_name": "tomatoes", "category": "food", "price": 1.99, "price":3}
talabat

#If a key is duplicated during dictionary creation, the last assignment display, and all previous values for that key are discarded.
# Out:
# {'item_name': 'tomatoes', 'category': 'food', 'price': 3}

# %%
# Let's change the pric , then do print(talabat) to see the result
talabat["pric"]=2
print(talabat)

### notice the above code, we did a typo error intentionally. Just run it as it is. 
# Notice that it adds a new key called 'pric' instead of updating the existing one
# because of the typo erro.
# Out:
# {'item_name': 'tomatoes', 'category': 'food', 'price': 3, 'pric': 2}

# %%
# Oops, we did a typo mistake, since Dictionary keys are unmodifiable, 
# we would need to remove it by using pop()
# Then change price to 2. print the dictionay again
talabat.pop("pric")
talabat["price"] = 2

print(talabat)
# Out:
# {'item_name': 'tomatoes', 'category': 'food', 'price': 2}

# %%
# Add two entries, fresh and assign it True & discount and assign it 0.15
talabat["fresh"] = True
talabat["discount"] = 0.15

print(talabat)
# Out:
# {'item_name': 'tomatoes', 'category': 'food', 'price': 2, 'fresh': True, 'discount': 0.15}

# %%
# Print all the keys using keys()
print(talabat.keys())

# print all the values using values()
print(talabat.values())

# print all (keys, values) using items()
print(talabat.items())
# Out:
# dict_keys(['item_name', 'category', 'price', 'fresh', 'discount'])
# dict_values(['tomatoes', 'food', 2, True, 0.15])
# dict_items([('item_name', 'tomatoes'), ('category', 'food'), ('price', 2), ('fresh', True), ('discount', 0.15)])

# %% [markdown]
# #### **Key Value Properties**

# %%
# Use the house dictionary for the following challenges
house = { "address": "123 Fake Street", "price": 750000, "bedrooms": 3}

# %%
# A. Print the number of bedrooms
print(house["bedrooms"])
# Out:
# 3

# %%
# B. Buyers can't find the house without a zip code! Add a zip_code property equal to "95404"
house["zip_code"] = 95404
house
# Out:
# {'address': '123 Fake Street',
#  'price': 750000,
#  'bedrooms': 3,
#  'zip_code': 95404}

# %%
# C. Our web designers want a statement reading: "This 3 bedroom house costs 750000"
#    Print that statement by accessing the values from the dictionary: do NOT "hard-code" the string!
print(f"This {house['bedrooms']} bedroom house costs {house['price']}")
# Out:
# This 3 bedroom house costs 750000

# %%
# D. We're getting a lot of interest in the house! Let's increase the price by 10%

house['price'] = house['price']*1.10

# %%
print(house)
# Out:
# {'address': '123 Fake Street', 'price': 825000.0000000001, 'bedrooms': 3, 'zip_code': 95404}

# %%
# E. Buyers are surprised at how small the house is. Let's add a square_feet property equal to 750
house['square_feet'] = 750
print(house)
# Out:
# {'address': '123 Fake Street', 'price': 825000.0000000001, 'bedrooms': 3, 'zip_code': 95404, 'square_feet': 750}

# %%
# F. We want to show off the value per foot. Print a message explaining the price per square foot.
# your print will be like:
# This home offers great value at only $1100.0 per square foot!

price_per_sqft = house['price'] / house['square_feet']
print(f"This home offers great value at only ${price_per_sqft:.1f} per square foot!")
# Out:
# This home offers great value at only $1100.0 per square foot!

# %%
# G. After 2 long hours on the market, the house has finally sold! Add a status property equal to "sold"

house['status'] = "sold"
house
# Out:
# {'address': '123 Fake Street',
#  'price': 825000.0000000001,
#  'bedrooms': 3,
#  'zip_code': 95404,
#  'square_feet': 750,
#  'status': 'sold'}

# %%
# H. Print the entire listing. You should see a dictionary similar to the following:
# {'address': '123 Fake Street', 'price': 825000.0, 'bedrooms': 3, 'zip_code': '95404', 'square_feet': 750, 'status': 'sold'}

print(house)
# Out:
# {'address': '123 Fake Street', 'price': 825000.0000000001, 'bedrooms': 3, 'zip_code': 95404, 'square_feet': 750, 'status': 'sold'}

# %% [markdown]
# ### **Python Librarian**

# %%
# 1.9 Python Librarian

authors = {
    "Arundhati Roy": {
        "genre": "literary fiction",
        "books": [
            "The God of Small Things",
            "The Ministry of Utmost Happiness"
        ],
        "active": True
    },
    "Brandon Sanderson": {
        "genre": "fantasy",
        "books": [
            "The Way of Kings",
            "Words of Radiance",
            "Oathbringer"
        ],
        "active": True,
        "phone": {
            "home": "(281) 330-8004",
            "work": "(877) CASH-NOW"
        }
    },
    "Kobo Abe": {
        "genre": "absurdist fiction",
        "books": [
            "The Woman in the Dunes",
            "The Face of Another"
        ],
        "active": False
    },
}

# %%
# A. Access and print Arundhati Roy's first book
print(authors["Arundhati Roy"]["books"][0])
# Out:
# The God of Small Things

# %%
# B. We need to contact Brandon at work: access and print their work phone number
authors["Brandon Sanderson"]["phone"]["work"]
# Out:
# '(877) CASH-NOW'

# %%
# C. Create a list composed of all the genres available in our library
genres = []  # this creates empty list for you. You need to use append() to add items
genres.append(authors["Arundhati Roy"]["genre"])
genres.append(authors["Brandon Sanderson"]["genre"])
genres.append(authors["Kobo Abe"]["genre"])

print(genres)
# Out:
# ['literary fiction', 'fantasy', 'absurdist fiction']

# %%
# D. Create a list of all books available in our library
books = []  # this creates empty list for you. You need to use append() to add items

roy_books = authors["Arundhati Roy"]["books"]
sanderson_books = authors["Brandon Sanderson"]["books"]
abe_books = authors["Kobo Abe"]["books"]

books.append(roy_books[0])
books.append(roy_books[1])

books.append(sanderson_books[0])
books.append(sanderson_books[1])
books.append(sanderson_books[2])

books.append(abe_books[0])
books.append(abe_books[1])

print(books)
# Out:
# ['The God of Small Things', 'The Ministry of Utmost Happiness', 'The Way of Kings', 'Words of Radiance', 'Oathbringer', 'The Woman in the Dunes', 'The Face of Another']

# %%
# E. Arundhati has decided to expand their range of genres and tackle non-fiction
#    Modify their "genre" property to now be a list that also includes non-fiction
genres.append('non-fiction')

# %%
# F. Brandon Sanderson is retiring. Change their active property to False.
#    BONUS: This means we should no longer contact them. Delete their "phone" property
authors["Brandon Sanderson"]["active"] = False
del authors["Brandon Sanderson"]["phone"]
print(authors["Brandon Sanderson"])
# Out:
# {'genre': 'fantasy', 'books': ['The Way of Kings', 'Words of Radiance', 'Oathbringer'], 'active': False}

# %% [markdown]
# ### Casting lists, tuples, sets, dictionary

# %%
l=[6,2,3,6,7,1,6,2]
# convert list -> tuple using tuple()
my_tuple = tuple(l)
print(my_tuple)
# Out:
# (6, 2, 3, 6, 7, 1, 6, 2)

# %%
# convert list -> set using set()
my_set = set(l)
print(my_set)
# Out:
# {1, 2, 3, 6, 7}

# %%
# convert list -> dictionary, use dict(). 
# Does it give you an error? why?
my_dict = dict(l)
# yes error because cannot convert dictionary update sequence element #0 to a sequence
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # convert list -> dictionary, use dict().
#       2 # Does it give you an error? why?
# ----> 3 my_dict = dict(l)
#       4
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
t=(6,2,3,6,7,1,6,2)
# convert tuple -> list  using list()
my_list = list(t)
print(my_list)
# Out:
# [6, 2, 3, 6, 7, 1, 6, 2]

# %%
# convert tuple -> set
my_set = set(t)
print(my_set)
# Out:
# {1, 2, 3, 6, 7}

# %%
# convert tuple -> dictionary
# Does it give you an error? why?
my_dict = dict(t)
# yes error because cannot convert dictionary update sequence element #0 to a sequence
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 # convert tuple -> dictionary
#       2 # Does it give you an error? why?
# ----> 3 my_dict = dict(t)
#       4 # yes error because cannot convert dictionary update sequence element #0 to a sequence
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
s={6,2,3,6,7,1,6,2}
# convert set -> list
my_list = list(s)
print(my_list)
# Out:
# [1, 2, 3, 6, 7]

# %%
# set -> tuple
my_tuple = tuple(s)
print(my_tuple)
# Out:
# (1, 2, 3, 6, 7)

# %%
# set -> dictionary
# Does it give you an error? why?
my_dict = dict(s)
# yes error cannot convert dictionary update sequence element #0 to a sequence
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 # set -> dictionary
#       2 # Does it give you an error? why?
# ----> 3 my_dict = dict(s)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
d={'Course':'DAI-7',"Room":306, "Building":'BIBF'}
# convert dictionary -> list
my_list = list(d.items())
print(my_list)
# Out:
# [('Course', 'DAI-7'), ('Room', 306), ('Building', 'BIBF')]

# %%
# dictionary -> tuple
print(tuple(d.items()))
# Out:
# (('Course', 'DAI-7'), ('Room', 306), ('Building', 'BIBF'))

# %%
# dictionary -> set
print(set(d.items()))
# Out:
# {('Room', 306), ('Building', 'BIBF'), ('Course', 'DAI-7')}

# %% [markdown]
# ### **OPTIONAL EXTRA PRACTICE(Solved)**

# %%
# OPTIONAL EXTRA PRACTICE:
# How many ways to print with variables
# Programming provides many ways of doing the same thing
# We've learned about concatenation and f-string interpolation so far
# Below, research and demonstrate four different ways of including variables in a string in python
# You don't need to understand exactly how they're working to get them to work!
day = "Sunday"
print(day + " is the best day of the week")
print(f"{day} is the best day of the week")
print("%s is the best day of the week" %day)
print("{} is the best day of the week".format(day))
# Out:
# Sunday is the best day of the week
# Sunday is the best day of the week
# Sunday is the best day of the week
# Sunday is the best day of the week
